# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from tabulate import tabulate as tab
import warnings
import generate_synthetic_data as gsd

# %%
def ref_plot(X, Y, Npulses = 1000, txt = 'training'):
    fig, axs = plt.subplots(1, 3, figsize=(14, 4))
    for i in range(Npulses):
        axs[0].plot(X[Y==1][i]);
        axs[0].set_title(f'{txt}: neutrons')
    for i in range(Npulses):
        axs[1].plot(X[Y==0][i]);
        axs[1].set_title(f'{txt}: gammas')
    for i in range(Npulses):
        axs[2].plot(X[Y==2][i]);
        axs[2].set_title(f'{txt}: pile-up')
    for i in range(0, 3):
            axs[i].set_xlabel("Pulse Sample", fontsize=12)
            axs[i].set_ylabel("Amplitude [V]", fontsize=12)
            axs[i].grid()
            axs[i].set_xlim(30, 100)
            # axs[i].set_ylim(0, 0.5)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Read Data

# %%
Case = 'Case10'
noise = 0.002 # 0.001, 0.002, 0.005, 0.010

# %%
data_train = np.load(f"Synthetic_Datasets/synthetic_training_{Case}_120k_noise_{noise}.npz")

X_train = data_train["X"]
Y_train = data_train["y"]
dt_train = data_train["meta"]

print(X_train.shape)
print(Y_train.shape)
print(dt_train.shape)

ref_plot(X_train, Y_train, Npulses = 100, txt = 'training'); # training: pulses must be normalized
# Out:
# (120000, 296)
# (120000,)
# (40000,)

# %%
data_val = np.load(f"Synthetic_Datasets/synthetic_validation_{Case}_480k_noise_{noise}.npz")

X_val = data_val["X"]
Y_val = data_val["y"]
dt_val = data_val["meta"]

print(X_val.shape)
print(Y_val.shape)
print(dt_val.shape)

ref_plot(X_val, Y_val, Npulses = 100, txt = 'validation'); # validation: pulses are not normalized
# Out:
# (480000, 296)
# (480000,)
# (160000,)

# %%
## norm
def normalize_to_peak_amplitude(pulses):
    return pulses / np.max(pulses, axis=1, keepdims=True)

ref_plot(normalize_to_peak_amplitude(X_val), Y_val, Npulses = 100, txt = 'validation'); # validation: pulses are not normalized

# %%
# mask = (Y_val==0) | (Y_val==1) 
# totals,ttr = gsd.get_psd_integrals(X_val[mask])

mask = (Y_val==0) | (Y_val==1) 
totals,ttr = gsd.get_psd_integrals(X_val)

plt.figure(figsize=(6, 5))
plt.hist2d(
    totals,
    ttr,
    bins=[300, 300],
    range=[[0, 8], [0, 0.6]],
    norm=LogNorm(),
    cmap="viridis"
)
plt.colorbar(label="LogCounts")
plt.xlabel('Total [V.samples]', fontsize = 15)
plt.ylabel("Tail-to-total ratio", fontsize = 15)
plt.tight_layout()
plt.show()

# %%
mask = (Y_val==0) | (Y_val==1)
totals_norm,ttr_norm = gsd.get_psd_integrals( normalize_to_peak_amplitude(X_val[mask]) )

plt.figure(figsize=(6, 5))
plt.hist2d(
    totals_norm,
    ttr_norm,
    bins=[300, 300],
    # range=[[0, 8], [0, 0.6]],
    norm=LogNorm(),
    cmap="viridis"
)
plt.colorbar(label="LogCounts")
plt.xlabel('Total [V.samples]', fontsize = 15)
plt.ylabel("Tail-to-total ratio", fontsize = 15)
plt.tight_layout()
plt.show()
