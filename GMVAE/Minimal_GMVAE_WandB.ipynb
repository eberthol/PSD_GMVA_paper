# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from tabulate import tabulate as tab
import types # to use dictionary as an object

# !pip3 install torch torchvision 
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# !pip3 install umap-learn
# import umap

#!pip3 install plotly
import plotly.graph_objects as go # interactive plots

# synthData_path = os.path.join('..', 'synthetic_data') |
# sys.path.append(synthData_path)
# import generate_synthetic_data as gsd

import gmvae_architecture as ga
import gmvae_performance_and_validation as gpv

import wandb

# %%
import warnings
# Specifically for sklearn/numpy matmul issues
warnings.filterwarnings('ignore', message='.*matmul.*')
# warnings.filterwarnings('ignore', category=RuntimeWarning)

# %% [markdown]
# # Train and log

# %%
### plan:
# 1. fix noise_level: 0.001, 50 epochs 
    # vary learning_rate 1e-3, 1e-4
    # batch_size 128, 100, 512
    # z_dim 8, 16, 32
    # alpha 50, 25, 1
# 2. fix noise_level: 0.05
    # vary learning_rate 1e-3, 1e-4
    # batch_size 128, 100, 512
    # z_dim 8, 16, 32
    # alpha 50, 25, 1

# %%
pathToDatasets = '../synthetic_data/Synthetic_Datasets'
wandb.init(
    project="GMVAE_paper",
    config={
        "learning_rate": 1e-3,  # 1e-4 in paper
        "epochs": 25,            # 100 in paper
        "batch_size": 128,      # 100 in paper
        "z_dim": 8,             # latent dimension (8 in paper)
        "alpha": 50,            # classification weight in the loss (50 in paper)
        "noise_level": 0.002,   # availale: 0.002
        "case": 'Case10'        # availale: 10
    }
)
config = wandb.config
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

data = np.load(f"{pathToDatasets}/synthetic_training_{config.case}_120k_noise_{config.noise_level}.npz")
X_train = data["X"]
Y_train = data["y"]
shifts_pileup_train = data["meta"]
config["L"] = X_train.shape[1] # 296

data = np.load(f"{pathToDatasets}/synthetic_validation_{config.case}_480k_noise_{config.noise_level}.npz")
X_val = data["X"]
X_val_norm = gpv.normalize_to_peak_amplitude(X_val)
Y_val = data["y"]
shifts_pileup_test = data["meta"]

model = ga.GMVAE(L=config.L, z_dim=config.z_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate) # weight_decay=1e-5

# sanity-checks: 
# randomize labels -> perofrmances should be BAD!
# Y_train = np.random.permutation(Y_train)
# train on gammas only 
# X_train = X_train[Y_train==0]
# Y_train = Y_train[Y_train==0]

train_loader = DataLoader(
    TensorDataset(
    torch.tensor(X_train, dtype=torch.float32),
    torch.tensor(Y_train, dtype=torch.long)
    ),
    batch_size=config.batch_size,
    shuffle=True,
    drop_last=True
)
val_loader = DataLoader(
    TensorDataset(
    torch.tensor(X_val_norm, dtype=torch.float32),
    torch.tensor(Y_val, dtype=torch.long)
    ),
    batch_size=config.batch_size,
    shuffle=False
)

# Training Loop
# Watch gradients
# log_freq=100 logs every 100 batches to keep your dashboard fast
wandb.watch(model, log="all", log_freq=100, log_graph=True)

analyzer = gpv.GMVAEAnalyzer(
    model=model,
    dataloader=train_loader
)
# Tell W&B to use 'epoch' as the X-axis for these specific keys
wandb.define_metric("Clustering/*", step_metric="epoch")
wandb.define_metric("silhouette_score", step_metric="epoch")
wandb.define_metric("reconstruction_sample", step_metric="epoch")
wandb.define_metric("latent_space", step_metric="epoch")

for epoch in range(config.epochs):
    # log every 5 epochs
    ga.train_epoch_wandb(model, train_loader, optimizer, device, alpha=config.alpha)
    if epoch % 5 == 0:
        score = gpv.log_clustering_quality(analyzer, epoch, sample_size=5000)
        print(f"Epoch {epoch}: Silhouette Score = {score:.4f}")
# ga.log_visualizations...

# Validation
# final_analyzer = gpv.GMVAEAnalyzer(model, val_loader, device=device)
# gpv.run_final_inference_report(final_analyzer, X_val, Y_val, dir="Inference")

# Optional
# train_analyzer = gpv.GMVAEAnalyzer(model, train_loader, device=device)
# gpv.run_final_inference_report(train_analyzer, X_train, Y_train, dir="Training")

# Data
## add plots for data (PSD), somehting else?

# test
final_analyzer = gpv.GMVAEAnalyzer(model, val_loader, device=device)
gpv.run_test_report(final_analyzer, prefix="Sanity")




# Finish the run
wandb.finish()
# Out:
# wandb: Currently logged in as: ebertholet (ebertholet-tel-aviv-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/Users/emiliebertholet/Desktop/DataAnalysis/PSD_GMVA_paper/GMVAE/wandb/run-20260126_102317-si96hml2</code>
# Syncing run <strong><a href='https://wandb.ai/ebertholet-tel-aviv-university/GMVAE_paper/runs/si96hml2' target="_blank">pious-serenity-109</a></strong> to <a href='https://wandb.ai/ebertholet-tel-aviv-university/GMVAE_paper' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ebertholet-tel-aviv-university/GMVAE_paper' target="_blank">https://wandb.ai/ebertholet-tel-aviv-university/GMVAE_paper</a>
# ...
